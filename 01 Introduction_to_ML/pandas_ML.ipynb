# %% [markdown]
# <a href="https://colab.research.google.com/github/1kalyan/ML-from-scratch/blob/main/01%20Introduction_to_ML/pandas_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Pandas
#
# 🍀Data Preprocessing in Machine Learning using Pandas
#
# ✨🌟Data preprocessing is required tasks for cleaning the data and making it suitable for a machine learning modelwhich also increase the accuracy and efficiency of a machine learning model.
#
# 🔥⚡️Pandas is an open source Python package that is mostly widely used for data science/data analysis and machine learning tasks. It is built on top of another package named Numpy, whisch provides support  for multi-dimensional arrays. Preprocessing is the process of doing a pre-analysis of data, in order to transform them into a standard and normalized format.
#
# 🌏🌍🌎Preprocessing involves the following aspects:
#
# - missing values
# - data standardization
# - data normalization
# - data mining

# %%
import pandas as pd

# %%
data = {
    "cars" : ["bmw", "honda", "suzuki","BYD"],
    "model": ["2007","2009","2008", "2023"],
    "passenger": ["5", "5","6","7"]
}
# print(data)
data
# Out:
# {'cars': ['bmw', 'honda', 'suzuki', 'BYD'], 'model': ['2007', '2009', '2008', '2023'], 'passenger': ['5', '5', '6', '7']}
# {'cars': ['bmw', 'honda', 'suzuki', 'BYD'],
#  'model': ['2007', '2009', '2008', '2023'],
#  'passenger': ['5', '5', '6', '7']}

# %%
#Convert the data into data frame
df = pd.DataFrame(data)
df
# Out:
#      cars model passenger
# 0     bmw  2007         5
# 1   honda  2009         5
# 2  suzuki  2008         6
# 3     BYD  2023         7

# %%
#comma seperated value
# save the file as a csv file

df.to_csv("/content/drive/MyDrive/Machine-learning/car data.csv")

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
#pandas Series
import pandas as pd
a = [1 , 7 ,2 ]
myVar = pd.Series(a)
print(myVar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
#create lables in pandas with index
a = [1,7,2]
myVar = pd.Series(a, index=["x","y","z"])
myVar
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
print(myVar["y"])
# Out:
# 7

# %%
#task: Create dataframe named df, with data calories and durations
data = {
    "calories": [420,380,390],
    "duration": [50,40,45]
}
df = pd.DataFrame(data)
df
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
#printing with the index using locate
# df.loc[1]
print(df.loc[1])
# Out:
# calories    380
# duration     40
# Name: 1, dtype: int64

# %%
import pandas as pd
data = {
    "calories": [420,380,390],
    "duration": [50,40,45],

}
df = pd.DataFrame(data ,  index = ["day1", "day2","day3"])
df
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
#accessing day2 data
df.loc["day2"]
# Out:
# calories    380
# duration     40
# Name: day2, dtype: int64

# %%
import pandas as pd
myData = {
    "name": "Kalyan",
    "semester": "6th sem",
    "subject": ["compiler desing","TOC","AI","DotNet","Graphics"],
    "marks": ["58","59","59","57","57"],
}
df = pd.DataFrame(myData , index= ["sub1","sub2","sub3","sub4","sub5"])
df.loc["sub3"].
# Out:
#         name semester          subject marks
# sub1  Kalyan  6th sem  compiler desing    58
# sub2  Kalyan  6th sem              TOC    59
# sub3  Kalyan  6th sem               AI    59
# sub4  Kalyan  6th sem           DotNet    57
# sub5  Kalyan  6th sem         Graphics    57

# %%
#clean pandas dataset.csv

import pandas as pd
df= pd.read_csv("/content/drive/MyDrive/Machine-learning/pandas_dataset.csv")
df
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01'    110       130     409.1
# 1         60  2020/12/02'    117       145     479.0
# 2         60  2020/12/03'    103       135     340.0
# 3         45  2020/12/04'    109       175     282.4
# 4         45  2020/12/05'    117       148     406.0
# 5         60  2020/12/06'    102       127     300.0
# 6         60  2020/12/07'    110       136     374.0
# 7        450  2020/12/08'    104       134     253.3
# 8         30  2020/12/09'    109       133     195.1
# 9         60  2020/12/10'     98       124     269.0
# 10        60  2020/12/11'    103       147     329.3
# 11        60  2020/12/12'    100       120     250.7
# 12        60  2020/12/12'    100       120     250.7
# 13        60  2020/12/13'    106       128     345.3
# 14        60  2020/12/14'    104       132     379.3
# 15        60  2020/12/15'     98       123     275.0
# 16        60  2020/12/16'     98       120     215.2
# ...

# %%
df.head()
# Out:
#    Duration         Date  Pulse  Maxpulse  Calories
# 0        60  2020/12/01'    110       130     409.1
# 1        60  2020/12/02'    117       145     479.0
# 2        60  2020/12/03'    103       135     340.0
# 3        45  2020/12/04'    109       175     282.4
# 4        45  2020/12/05'    117       148     406.0

# %%
df.tail()
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 27        60  2020/12/27'     92       118     241.0
# 28        60  2020/12/28'    103       132       NaN
# 29        60  2020/12/29'    100       132     280.0
# 30        60  2020/12/30'    102       129     380.3
# 31        60  2020/12/31'     92       115     243.0

# %%
#lets see the shape of the dataset
#total rows and columns
df.shape
# Out:
# (32, 5)

# %%
#examine of data tpye
data_types = df.dtypes
data_types
# Out:
# Duration      int64
# Date         object
# Pulse         int64
# Maxpulse      int64
# Calories    float64
# dtype: object

# %%
df.nunique()
# Out:
# Duration     4
# Date        30
# Pulse       15
# Maxpulse    24
# Calories    26
# dtype: int64

# %%
isnull = df.isnull()

# %%
isnull_count = isnull.sum()
print(isnull_count)
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
#total nulls in dataset
total_isnull_count = isnull.sum().sum()
print("total nulls:",total_isnull_count)
# Out:
# total nulls: 3

# %%
#replace single quote with space in date
df['Date'] = df['Date'].replace("'", "", regex=True)
df
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
#handle null values, return dataframe with no empty cells
#we can use df.dropna(), it will remove empty cells but will not change the dataframe
#if we want dataframe to be changed. simply use inplace=true

new_df = df.dropna(inplace=False)
new_df
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
#che
isnull_count_newdf = new_df.isnull().sum().sum()
isnull_count_newdf
# Out:
# 0

# %%
#another way of handling the null. values is by replacing the null values
df.fillna(130 , inplace=True)
df
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
df = pd.read_csv("/content/drive/MyDrive/Machine-learning/pandas_dataset.csv")
df
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01'    110       130     409.1
# 1         60  2020/12/02'    117       145     479.0
# 2         60  2020/12/03'    103       135     340.0
# 3         45  2020/12/04'    109       175     282.4
# 4         45  2020/12/05'    117       148     406.0
# 5         60  2020/12/06'    102       127     300.0
# 6         60  2020/12/07'    110       136     374.0
# 7        450  2020/12/08'    104       134     253.3
# 8         30  2020/12/09'    109       133     195.1
# 9         60  2020/12/10'     98       124     269.0
# 10        60  2020/12/11'    103       147     329.3
# 11        60  2020/12/12'    100       120     250.7
# 12        60  2020/12/12'    100       120     250.7
# 13        60  2020/12/13'    106       128     345.3
# 14        60  2020/12/14'    104       132     379.3
# 15        60  2020/12/15'     98       123     275.0
# 16        60  2020/12/16'     98       120     215.2
# ...

# %%
df['Calories'].fillna(130, inplace=True)
df
# Out:
# <ipython-input-31-5cd9109089a2>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Calories'].fillna(130, inplace=True)
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01'    110       130     409.1
# 1         60  2020/12/02'    117       145     479.0
# 2         60  2020/12/03'    103       135     340.0
# 3         45  2020/12/04'    109       175     282.4
# 4         45  2020/12/05'    117       148     406.0
# 5         60  2020/12/06'    102       127     300.0
# ...

# %%
df['Date'] = df['Date'].replace("'" , "", regex=True)
df
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
#fill specific with mean, median and mode
df = pd.read_csv('/content/drive/MyDrive/Machine-learning/pandas_dataset.csv')
mean_value = df['Calories'].mean();
df['Calories'].fillna(mean_value , inplace = True)
df
# Out:
# <ipython-input-35-837e4172eb3a>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Calories'].fillna(mean_value , inplace = True)
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01'    110       130    409.10
# 1         60  2020/12/02'    117       145    479.00
# 2         60  2020/12/03'    103       135    340.00
# 3         45  2020/12/04'    109       175    282.40
# 4         45  2020/12/05'    117       148    406.00
# 5         60  2020/12/06'    102       127    300.00
# ...

# %%
df['Date'] = df['Date'].replace("'" , "", regex=True)
df
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130    409.10
# 1         60  2020/12/02    117       145    479.00
# 2         60  2020/12/03    103       135    340.00
# 3         45  2020/12/04    109       175    282.40
# 4         45  2020/12/05    117       148    406.00
# 5         60  2020/12/06    102       127    300.00
# 6         60  2020/12/07    110       136    374.00
# 7        450  2020/12/08    104       134    253.30
# 8         30  2020/12/09    109       133    195.10
# 9         60  2020/12/10     98       124    269.00
# 10        60  2020/12/11    103       147    329.30
# 11        60  2020/12/12    100       120    250.70
# 12        60  2020/12/12    100       120    250.70
# 13        60  2020/12/13    106       128    345.30
# 14        60  2020/12/14    104       132    379.30
# 15        60  2020/12/15     98       123    275.00
# 16        60  2020/12/16     98       120    215.20
# ...
